# %% [markdown]
# # 09-05-2025

# %% [markdown]
# #### Exception ---> Base class

# %%
try:
    5/0
except Exception as e:
    print(f"Exception caught: {e}")

except ZeroDivisionError:
    print(f"Error caught: {ZeroDivisionError}")

print("Code executed successfully")
# Out:
# Exception caught: division by zero
# Code executed successfully

# %%
try:
    print(989//3)
except Exception as e:
    print(f"Exception caught: {e}")
else:
    print("This block will execute if no exception occurs")
# Out:
# 329
# This block will execute if no exception occurs

# %%
try:
    f = open("non_existent_file.txt", "r")
    print(f.read())
except Exception as e:
    print(f"Exception caught: {e}")

else:
    print("File read successfully")
    f.close()
    print("File closed successfully")
finally:
    print("This block always executes, regardless of exceptions")
# Out:
# Exception caught: [Errno 2] No such file or directory: 'non_existent_file.txt'
# This block always executes, regardless of exceptions

# %% [markdown]
# #### WAP that tries to open a file named data.txt . If the file doesn't exist catch the exception and print a user firendly msg.

# %% [markdown]
# #### Create a custom exception called invalid age error. WAP that accepts an age input and raises invalid age error if the age is less than 18.
