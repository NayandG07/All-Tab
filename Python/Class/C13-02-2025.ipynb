# %% [markdown]
# # 13-02-2025

# %%
a = "I love apples, apples are my favorite fruit."
a.find("apples")
a.index("are")
# Out:
# 22

# %%
b = "Python"
print(b.center(10,"-")) # because the string is 6 characters long, it will be centered in a 10 character space with dashes
# Out:
# --Python--

# %% [markdown]
# ## Assignment

# %%
s = "Dhiman"
s.upper()
# Out:
# 'DHIMAN'

# %%
s.split(",") # split the string into a list of strings
# Out:
# ['Dhiman']

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s.isdigit()
# Out:
# False

# %%
a = "I love apples"
a.replace("apples", "Banana")
# Out:
# 'I love Banana'

# %%
a.find("apples")
# Out:
# 7

# %%
a.swapcase() # Swap case of the string
# Out:
# 'i LOVE APPLES'

# %%
a.isalnum() # False because of spaces in the string
# Out:
# False

# %%
a.startswith("They")
# Out:
# False

# %%
a.endswith("Hi")
# Out:
# False

# %%
a.endswith("les")
# Out:
# True

# %%
a.count("p")
# Out:
# 2

# %%
s1 = "Hello, how are you, are you reading Python"
print(s1.split(","))
# Out:
# ['Hello', ' how are you', ' are you reading Python']
