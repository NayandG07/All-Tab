# %%
a = input("Enter your age:")
print(a)
# Out:
# Enter your age:29
# 29

# %%
# typecasting
a = float(input())
print(type(a))
# Out:
# 32
# <class 'float'>

# %%
a = input("Enter your name: ")
b = int(input("ENter your age:"))
c = input("Enter your father's name : ")
print("=================================")
print("This is your name = ", a)
print("This is your age = ", b)
print("This is your fatehr name = ", c)

# %%
# operators 
+
-
*
**  ===>  2**3
a = int(input("enter the no."))
b = int(input("enter the second no."))

c = a+b
print("your answer = ", c)

# %%
a = int(input("enter the no."))
b = int(input("enter the second no."))

c = a+b
print("your answer = ", c)

# %%
a = int(input("enter the no."))
b = int(input("enter the second no."))

c = a**b
print("your answer = ", c)

# %%
a = int(input("enter the no."))
b = int(input("enter the second no."))

c = a*b
print("your answer = ", c)

# %%
# Division are of 3 types
# / ==> Single slash  = > Gives quotient value in float form
# // ==>  Q ==> gives integer form 
# % ==> Modulus ==> R => integer

# %%
a = int(input("enter the no."))
b = int(input("enter the second no."))

c = a%b
print("your answer = ", c)

# %%
# Do all the operations in 1 cell. by taking input

# %%
# Find the area of Square

# %%
# Area of circle

# %%
#Volume of cone

# %%
# take User P B and find hypotenus

# %%
# Area of cone

# %%
# Logical opeartor

a = 10
b = 9
c = 20

print(a>b and b>c)


print(a>b or b>c)

print(not(a>b))
