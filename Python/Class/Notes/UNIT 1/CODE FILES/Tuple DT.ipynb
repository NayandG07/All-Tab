# %% [markdown]
# ## Tuple
# They are used to store multiple items in a single variable/
# A tuple is a collection which is ordered and unchangeable. It is wriitten with round brackets

# %%
fruits = ("apple", "banana", "cherry")   # Standard Method
print(fruits)
# Out:
# ('apple', 'banana', 'cherry')

# %%
fruits = ("apple", "banana", "cherry", "banana")   # Allow Duplicates
print(fruits)

# %%
# Count() Method

nums = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

nums.count(5)
# Out:
# 2

# %%
# Index() Method

nums = (1, 3, 7, 8, 7, 5, 4, 6, 8, 5)

nums.index(6)
# Out:
# 7

# %%
#Min() & Max() Method

nums = (0, 3, 7, 8, 7, 5, 4, 6, 8, 5)

min(nums)
# Out:
# 0

# %%
max(nums)
# Out:
# 8

# %%
a = "good morning everyone"
a = list(a)
print(a)
# Out:
# ['g', 'o', 'o', 'd', ' ', 'm', 'o', 'r', 'n', 'i', 'n', 'g', ' ', 'e', 'v', 'e', 'r', 'y', 'o', 'n', 'e']

# %%
a = (10,20,'rohan', 400, "ram")

print(a,len(a),type(a))

# %%
# string function
a ="good morning everyone"

a = a.split()  # split( ) helps to find the spaces and give each word
print(a)
# Out:
# ['good', 'morning', 'everyone']

# %%
a = "rohan"
a = list(a)
print(a)
# Out:
# ['r', 'o', 'h', 'a', 'n']

# %%
a = (10,20,'rohan', 400, "ram")
a =list(a)
print(a)

# %%
### Question 
# just make this list like   [10,20,[30,40,50,[5000,6000,7000],60,70],80,90] 
a=[10,20,[30,40,50,[5000,6000],60,70],80,90]

b = a[2][3]
b.append(7000)

print(a)

# %%
## Home work/...
# make this as tuple and do the same question for that tuple

a=[10,20,[30,40,50,[5000,6000],60,70],80,90]

b = tuple(a)
print(b)

# %%
# inser 6000 in the inner most tuple
a=(10,20,30,(300,400,(5000,7000),500),40,50)

a =list(a)
print(a)
b = list(a[3])
print(b)
c = list(b[2])
print(c)

d = c.insert(6000,1)
print(d)
