# %% [markdown]
# # 24-02-2025

# %% [markdown]
# ###### Absent

# %% [markdown]
# ## Qs.1 WAP that takes a user input of a string and prints the string in uppercase and also in reverse order.

# %%
a = input("Enter a string: ")
print(a.upper())
print(a[::-1])
# Out:
# COSMOS
# somsoc

# %% [markdown]
# ## Qs.2 d = "Floccinaucinhifiplication"
# ###     count no. of 'i' in 'd'

# %%
d = "Floccinaucinhifiplication"
print(d.count("i"))
# Out:
# 6

# %% [markdown]
# ## Qs.3 WAP that takes a user input of a string and checks if it is a palindrome or not.

# %%
a = input("Enter a string: ")
b = a[::-1]
if(a==b):
    print("The string is a palindrome")
else:
    print("The string is not a palindrome")
# Out:
# The string is a palindrome

# %% [markdown]
# ## Qs.4 WAP to concatinate two strings and prints the result.

# %%
a = "Hello"
b = "World"
print(a+" "+b)
# Out:
# Hello World

# %% [markdown]
# ## Qs.5 WAP that replaces all occurances of a character in a string with a new character.

# %%
a = "This is a Java program that I'm interested in."
print(a.replace("Java","Python"))
# Out:
# This is a Python program that I'm interested in.

# %%
a,b = 5,12
print(f'Sum:{a+b}; Division:{(a/b):.1f}, Multiplication:{a*b},Substract:{a-b}')
# Out:
# Sum:17; Division:0.4, Multiplication:60,Substract:-7

# %%
# print('Pankaj's home')
print('Pankaj\'s home')
# Out:
# Pankaj's home
