# %% [markdown]
# # 29-01-2025

# %%
var = 10
print(type(var))

var = "Hello"
print(type(var))
# Out:
# <class 'int'>
# <class 'str'>

# %%
import string
print(string.ascii_letters)
print(string.ascii_lowercase)
print(string.ascii_uppercase)
print(string.digits)
print(string.whitespace)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ
# abcdefghijklmnopqrstuvwxyz
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789

# %% [markdown]
# #### Parameter --> value inside the parenthesis

# %%
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
a = "N"
b = 'N'
c = '''N'''
d = "Home's"
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(a)
print(b)
print(c)
print(d)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# N
# N
# N
# Home's

# %% [markdown]
# ##### PVM = Python Virtual Machine
