# %% [markdown]
# # 07-04-2025

# %%
def greet(name):
    print("Hello, "+name+"!")

greet("Python")
x = greet("World")
print(x)
print(greet("Again"))
# Out:
# Hello, Python!
# Hello, World!
# None
# Hello, Again!
# None

# %%
def greet(name):
    return ("Hello, "+name+"!")

print(greet("Python")) 
x = greet("World")
print(x)
print(greet("Again"))
# Out:
# Hello, Python!
# Hello, World!
# Hello, Again!

# %%
def cube(x):
    return x*x*x

num = 10
print("Cube of", num, "is", cube(num))
# Out:
# Cube of 10 is 1000

# %%
def display(str,int_x,float_y):
    print("String: ", str)
    print("Integer: ", int_x)
    print("Float: ", float_y)

display(float_y=1.5, str="Hello", int_x=10)
# Out:
# String:  Hello
# Integer:  10
# Float:  1.5

# %%
def display(salary, name, age):
    print("Name: ", name)
    print("Age: ", age)
    print("Salary: ", salary)

display(100000000, "John", 45)
# Out:
# Name:  John
# Age:  45
# Salary:  100000000

# %% [markdown]
# #### Default parameter should be at the last of the parenthesis.

# %%
def display(name,marks,course="B. Tech"):
    print("Course is: ",name)
    print("The mnarks is: ",marks)
    print("Name is: ",course)
display(name="Kartik", marks=90) # Error: positional argument follows keyword argument
# Out:
# Course is:  Kartik
# The mnarks is:  90
# Name is:  B. Tech

# %% [markdown]
# ### Modules

# %%
import sys
print("Python Path= ", sys.path)
# Out:
# Python Path=  ['c:\\Users\\nayan\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'c:\\Users\\nayan\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'c:\\Users\\nayan\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'c:\\Users\\nayan\\AppData\\Local\\Programs\\Python\\Python313', '', 'C:\\Users\\nayan\\AppData\\Roaming\\Python\\Python313\\site-packages', 'C:\\Users\\nayan\\AppData\\Roaming\\Python\\Python313\\site-packages\\win32', 'C:\\Users\\nayan\\AppData\\Roaming\\Python\\Python313\\site-packages\\win32\\lib', 'C:\\Users\\nayan\\AppData\\Roaming\\Python\\Python313\\site-packages\\Pythonwin', 'c:\\Users\\nayan\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages']

# %%
# import os
# path = "C:\Windows\System32"
# os.rmdir(path)

# %%
from math import pi
print("Pi= ", pi)
# Out:
# Pi=  3.141592653589793

# %%
from math import sqrt as square_root
print(square_root(81))
# Out:
# 9.0

# %%
print("Hello")
print("Name of the module is: ", __name__)
# Out:
# Hello
# Name of the module is:  __main__

# %% [markdown]
# ### WAP to calculate compound interest given the principle, rate of interest and number of years

# %%
def CI(p,r,t):
    return (p*r*t)/100

principle = int(input("Enter the principle: "))
rate = int(input("Enter the rate: "))
time = int(input("Enter the time: "))
print("Compound Interest is: ", CI(principle, rate, time))
# Out:
# Compound Interest is:  3000.0

# %% [markdown]
# ### WAP that converts temperature given in celsius in farenheit

# %%
def temperature(C,F):
    return C*9/5 + 32

celsius = int(input("Enter the temperature in Celsius: "))
fahrenheit = int(input("Enter the temperature in Fahrenheit: "))
print("Temperature in Celsius: ", temperature(celsius, fahrenheit))

# %%
import MyModule
print("MyModule str = ", MyModule.str)
MyModule.display()
print("Name of calling module is: ", __name__)
# Out:
# MyModule str =  Welcome to the world of Python!
# Hello from MyModule!
# Name of the module: MyModule
# Name of calling module is:  __main__

# %%
from MyModule import str, display
display()
# Out:
# Hello from MyModule!
# Name of the module: MyModule

# %%
import math
print("PI= ",math.pi)
print("Euler's number= ",math.e)
# Out:
# PI=  3.141592653589793
# Euler's number=  2.718281828459045

# %% [markdown]
# ### Calculate the factorial of 5 using user defined function.

# %%
def factorial(n):
    if n==0 or n==1:
        return 1
    else:
        return n*factorial(n-1)
    
num = int(input("Enter a number: "))

if num < 0:
    print("Factorial of negative numbers is not possible")
else:
    print("Factorial of ", num, " is ", factorial(num))
# Out:
# Factorial of  5  is  120

# %%
def fact(f=1):
    for i in range(1,6):
        f*=i
    print("The factorial of 5 is: ",f)

fact()
# Out:
# The factorial of 5 is:  120

# %% [markdown]
# ### WAP to that accepts a number n as input and returns the average of number from 1 to n.

# %%
def average(n):
    if n <= 0:
        return 0
    sum = n*(n+1)/2
    return sum/n

num = int(input("Enter a number: "))
print(f"Average of first {num} numbers is: ", average(num))
# Out:
# Average of first 4 numbers is:  2.5

# %% [markdown]
# ### WAP to calculate the area of a triangle using function.

# %%
def TriangleArea(base, height):
    return 0.5 * base * height

base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))
print("Area of the triangle is: ", TriangleArea(base, height))
# Out:
# Area of the triangle is:  7.5

# %% [markdown]
# ### WAP using function to calculate X^y where y be either or -ve or +ve. Pass dictionary as an argument to the function.

# %%
def power(dict):
    if "x" not in dict or "y" not in dict:
        return "X and Y are required"
    return dict["x"]**dict["y"] # dict["x"] means the value of x in the dictionary

X = int(input("Enter the value of X: "))
Y = int(input("Enter the value of Y: "))
print("Power of X^Y is: ", power({"x": X, "y": Y}))
# Out:
# Power of X^Y is:  16
